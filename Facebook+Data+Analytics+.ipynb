# %% [markdown]
# # 1.  Scrapper les données de la page facebook Tunisie Télécom

# %%
import requests 
import time
import pickle
import random

token="EAACEdEose0cBAKLUJXatW74LPMZCFjlLUzHsu6lCZApqVOeUldf19xdwSoLMSmqu3MfauNlb9nAV9oZAgZCIoCZBMLTNdKTcpqnZBRM3tSyNLGwS0dA0jRKPnsFFncDx5lotDWU3WWjjYIuZBQRXPXjuSkN8x7Wf854b0cbrwwxdmBpmoGO1EHK46lnTArZChsgZD"
       
def req_facebook(req):
    r = requests.get("https://graph.facebook.com/v2.8/" + req , {'access_token' : token})
    return r

req_facebook("TunisieTelecom?fields=posts{comments.limit(0).summary(true),likes.limit(0).summary(true),created_time,message,id}")
r=req_facebook("TunisieTelecom?fields=posts{comments.limit(0).summary(true),likes.limit(0).summary(true),created_time,message,id}")
results= r.json()

data=[]
results =results['posts']

i=0
while True:

    try:
        time.sleep(random.randint(3,6))
        data.extend(results['data'])
        r=requests.get(results['paging']['next'])
        results= r.json()    
        i += 1
   
        if i > 200:
            break
    except:
        print ("done")
        break
# Out:
# done

# %% [markdown]
# # 2.  Visualiser la base de données

# %%
 import pandas as pd
import string
from operator import itemgetter 

#Voir les détails sur le 1er post
data[0]
# Out:
# {'comments': {'data': [],
#   'summary': {'can_comment': True, 'order': 'ranked', 'total_count': 2}},
#  'created_time': '2018-06-30T13:00:02+0000',
#  'id': '117627008288878_1977214322330128',
#  'likes': {'data': [],
#   'summary': {'can_like': True, 'has_liked': False, 'total_count': 31}},
#  'message': 'كيف كل أول نهار أحد من الشهر جديد، تنجموا تزوروا المتاحف إلي في تونس الكل بلاش 😍'}

# %%
#voir les détails sur le 2ème .. 6ème post
data[1:5]
# Out:
# [{'comments': {'data': [],
#    'summary': {'can_comment': True, 'order': 'ranked', 'total_count': 3}},
#   'created_time': '2018-06-29T18:00:01+0000',
#   'id': '117627008288878_1977181962333364',
#   'likes': {'data': [],
#    'summary': {'can_like': True, 'has_liked': False, 'total_count': 47}},
#   'message': 'مغروم بالكتب 📚 و les magazines📰، من اليوم تبع كل ماهو جديد😃 على YouScribe و خليك à jour😉\nباش تعرف أكثر معلومات إنزل هنا : https://goo.gl/V64oBv'},
#  {'comments': {'data': [],
#    'summary': {'can_comment': True, 'order': 'ranked', 'total_count': 40}},
#   'created_time': '2018-06-28T13:10:00+0000',
#   'id': '117627008288878_1975296145855279',
#   'likes': {'data': [],
#    'summary': {'can_like': True, 'has_liked': False, 'total_count': 1212}},
#   'message': 'توانسة شاركوا معانا و إتصالات تونس خلاتهم يعيشو الحلم و يساندوا تونس 🇹🇳👌\nهاي رسالتهم قبل الماتش 🇹🇳👌⚽'},
#  {'comments': {'data': [],
#    'summary': {'can_comment': True, 'order': 'ranked', 'total_count': 8}},
#   'created_time': '2018-06-27T20:33:24+0000',
#   'id': '117627008288878_1974328142618746',
#   'likes': {'data': [],
#    'summary': {'can_like': True, 'has_liked': False, 'total_count': 67}},
#   'message': 'تبع عالم يوسف المساكني ⚽🏆\nو أبعثت مجانا Y7 على 85557'},
#  {'comments': {'data': [],
#    'summary': {'can_comment': True, 'order': 'ranked', 'total_count': 28}},
#   'created_time': '2018-06-27T12:29:25+0000',
#   'id': '117627008288878_1973689936015900',
#   'likes': {'data': [],
#    'summary': {'can_like': True, 'has_liked': False, 'total_count': 150}},
#   'message': 'شارك مع 🎊 TT Quiz 🎊 كيما Karamti Chawki باش تدخل فالقرعة و تربح برشا كادوات'}]

# %%
#visualiser les détails sur le dernier post scrapé
data[-1]
# Out:
# {'comments': {'data': [],
#   'summary': {'can_comment': True, 'order': 'ranked', 'total_count': 41}},
#  'created_time': '2016-08-18T08:46:35+0000',
#  'id': '117627008288878_1240814119303489',
#  'likes': {'data': [],
#   'summary': {'can_like': True, 'has_liked': False, 'total_count': 900}}}

# %%
#longueur de la base 
len(data)
# Out:
# 1375

# %%
#type de la base
type(data)
# Out:
# list

# %% [markdown]
# # 3.  Pre-processing de la base de données

# %% [markdown]
# ## Normaliser la base

# %%
df2 = pd.io.json.json_normalize(data=data)
df2.head()
df2.columns
# Out:
# Index(['comments.data', 'comments.summary.can_comment',
#        'comments.summary.order', 'comments.summary.total_count',
#        'created_time', 'id', 'likes.data', 'likes.summary.can_like',
#        'likes.summary.has_liked', 'likes.summary.total_count', 'message'],
#       dtype='object')

# %% [markdown]
# ## Effacer quelques colonnes

# %%
df2.columns[0]
df2.drop('comments.data' , 1 , inplace=True)
df2.drop( df2.columns[[0,1,5,6,7]] , 1 , inplace=True)

# %% [markdown]
# ## Renommer les colonnes

# %%
df2.rename( columns= { "comments.summary.total_count" : "total_comments"} , inplace=True)
df2.rename( columns= { "likes.summary.total_count" : "total_likes"} , inplace=True)

# %% [markdown]
# ## Effacer les valeurs nulles

# %%
df2.fillna("",inplace=True)

# %% [markdown]
# ## Visualiser la base nettoyée

# %%
df2.head(10)
# Out:
#    total_comments              created_time                                id  \
# 0               2  2018-06-30T13:00:02+0000  117627008288878_1977214322330128
# 1               3  2018-06-29T18:00:01+0000  117627008288878_1977181962333364
# 2              40  2018-06-28T13:10:00+0000  117627008288878_1975296145855279
# 3               8  2018-06-27T20:33:24+0000  117627008288878_1974328142618746
# 4              28  2018-06-27T12:29:25+0000  117627008288878_1973689936015900
# 5             279  2018-06-26T18:00:01+0000  117627008288878_1972342666150627
# 6              73  2018-06-26T17:00:02+0000  117627008288878_1972299202821640
# 7              25  2018-06-26T12:14:12+0000  117627008288878_1971965562855004
# 8             389  2018-06-24T20:00:00+0000  117627008288878_1969407523110808
# 9             105  2018-06-24T12:00:01+0000  117627008288878_1967651363286424
#
#    total_likes                                            message
# 0           31  كيف كل أول نهار أحد من الشهر جديد، تنجموا تزور...
# 1           47  مغروم بالكتب 📚 و les magazines📰، من اليوم تبع ...
# 2         1212  توانسة شاركوا معانا و إتصالات تونس خلاتهم يعيش...
# 3           67  تبع عالم يوسف المساكني ⚽🏆\nو أبعثت مجانا Y7 عل...
# 4          150  شارك مع 🎊 TT Quiz 🎊 كيما Karamti Chawki باش تد...
# 5         5554  التوانسة أبدعو في روسيا و العالم الكل يشهد بين...
# 6          395  مع Netbox Internet \nبرنشي كونكتيي و الـ 25Go ...
# 7          128  شارك مع 🎊 TT Quiz 🎊 كيما Heribi Hamdi و إلا Ja...
# 8         9135        عصام الشوالي : عمري ماريت توانسة كيف هكا 🇹🇳
# 9         5893  مع  les nouveaux forfaits OH!Méga\nالconnexion...

# %% [markdown]
# # 4.  Analyser la base de données

# %% [markdown]
# ## Donner les 10 publications les plus commentées

# %%
#Most commented posts
df2.sort_values('total_comments',inplace=True,ascending=False)
top_comments=df2.head(10)
top_comments
# Out:
#      total_comments              created_time  \
# 483           22963  2018-01-01T17:46:47+0000
# 669           14904  2017-08-09T10:52:28+0000
# 216           10549  2018-05-10T11:30:01+0000
# 829            9665  2017-04-19T09:20:44+0000
# 775            6407  2017-05-25T19:42:20+0000
# 233            6250  2018-05-02T16:21:00+0000
# 606            5845  2017-09-29T18:58:46+0000
# 555            3180  2017-11-11T18:55:46+0000
# 13             2871  2018-06-22T17:03:36+0000
# 947            1964  2017-02-15T19:02:00+0000
#
#                                    id  total_likes  \
# 483  117627008288878_1761990677185828         3320
# 669  117627008288878_1615041551880742        11574
# 216  117627008288878_1912684712116423         3745
# 829  117627008288878_1496174600434105         1456
# 775  117627008288878_1531789463539285         5602
# 233  117627008288878_1904195626298665        56709
# 606  117627008288878_1665823723469191         2113
# 555  117627008288878_1707092332675663        23074
# 13   117627008288878_1965937463457814         9433
# 947  117627008288878_1425322067519359          421
#
#                                                message
# 483  حفل العام الجديد بالكادوات 🎉🎁🎀\n\n العب و اربح...
# 669  لعبتنا اليوم فيها تساكر لسهريّة مهرجان قرطاج ا...
# 216  شنية الرقم الناقص في السلسلة ؟ 🤔\nطلع معانا وا...
# 829  لعبتنا فيها تاليفون للولاد و تاليفون للبنات📱.....
# 775  بمناسبة عيد الأمهات، اتصالات تونس تودكم بأعز ا...
# 233  YA ROUSSIA JAYIN يا روسيا جايين 2\n#YRJ #Tunis...
# 606  تحب تربح تليفون ؟؟📱🎉\nساهل ياسر ماعليك كان تكت...
# 555  يااا روووسيااا جااييين و جااييين هاو جاااييين ...
# 13   نقولو ماناش مروحين 💪 توا جات روح جديدة ، نغمة ...
# 947  لعبتنا اليوم لازمتها عينين قويين.. 😅👀\nدور يسا...

# %% [markdown]
# ## Donner les urls des 10 publications les plus commentées

# %%
##ids of the 10 top commented posts
top_comments_id=top_comments['id']
top_comments_id

##urls of the 10 top commented posts
for i,x in top_comments_id.iteritems():
    print ('https://www.facebook.com/'+x )
# Out:
# https://www.facebook.com/117627008288878_1761990677185828
# https://www.facebook.com/117627008288878_1615041551880742
# https://www.facebook.com/117627008288878_1912684712116423
# https://www.facebook.com/117627008288878_1496174600434105
# https://www.facebook.com/117627008288878_1531789463539285
# https://www.facebook.com/117627008288878_1904195626298665
# https://www.facebook.com/117627008288878_1665823723469191
# https://www.facebook.com/117627008288878_1707092332675663
# https://www.facebook.com/117627008288878_1965937463457814
# https://www.facebook.com/117627008288878_1425322067519359

# %% [markdown]
# ## Donner les 10 publications qui ont obtenu plus de likes

# %%
##Most Liked Posts 
df2.sort_values('total_likes',inplace=True,ascending=False)
top_likes = df2.head(10)['id']

# %% [markdown]
# ## Donner les urls des 10 publications qui ont obtenu plus de likes

# %%
#urls of the 10 top commented posts
for i,x in top_likes.iteritems():
    print ('https://www.facebook.com/'+x )
# Out:
# https://www.facebook.com/117627008288878_1904195626298665
# https://www.facebook.com/117627008288878_1707092332675663
# https://www.facebook.com/117627008288878_1390483674336532
# https://www.facebook.com/117627008288878_1856541627730732
# https://www.facebook.com/117627008288878_1879691842082377
# https://www.facebook.com/117627008288878_1881338555251039
# https://www.facebook.com/117627008288878_1374836439234589
# https://www.facebook.com/117627008288878_1879693382082223
# https://www.facebook.com/117627008288878_1953010871417140
# https://www.facebook.com/117627008288878_1813043068747255

# %%
mapping = dict.fromkeys(map(ord, string.punctuation))

#Créer une fonction qui compte les mots dans les messages des publications    
def count_words(df):    
    
    words={}

    for m in df2['message']:
        try:
            seperated_words=m.split(' ')
        except:
            pass
           # print "ERROR"+str(m) 
        for word in seperated_words:
                word=word.strip()
                word=word.lower()
                
                word=word.translate(mapping) # Removes any punctation
                
                if word in words:
                    words[word]+=1
                else:
                    words[word]=1
    print("done counting words")
    return words

words=count_words(df2)
# Out:
# done counting words

# %%
words
# Out:
# {'ya': 2,
#  'roussia': 2,
#  'jayin': 1,
#  'يا': 16,
#  'روسيا': 9,
#  'جايين': 14,
#  '2\nyrj': 1,
#  'tunisie': 61,
#  'yaroussiajayin': 1,
#  'يااا': 1,
#  'روووسيااا': 1,
#  'جااييين': 2,
#  'و': 498,
#  'هاو': 5,
#  'جاااييين': 1,
#  'اتصلات': 2,
#  'تونس': 161,
#  'ديما': 22,
#  'مع': 174,
#  'عشاق': 3,
#  'المنتخب': 18,
#  '': 8725,
#  '🇹🇳🇹🇳🇹🇳': 2,
#  '😃🤣😎🎤⚽️✈️🇹🇳🇹🇳': 1,
#  'لكلنا': 7,
#  'نستناو': 2,
#  'في': 404,
#  'الmatch': 1,
#  'بالدقيقة': 1,
#  'الدرج': 1,
#  '⌚️⚽️\nلكلنا': 1,
#  'نحبوا': 10,
#  'نشوفوا': 1,
#  'الكورة': 4,
#  'الشبكة': 1,
#  '⚽️😄😍\nحاضرين': 1,
#  'لتشجيع': 4,
#  '؟': 73,
#  '🇹🇳🎉💪💯\nتابعونا': 1,
#  'على': 258,
#  'مواقعنا': 1,
#  '📱💻httpbitly2hplrvy\nfacebook': 1,
#  'twitter': 7,
#  'instagram': 16,
#  'et': 100,
#  'snapchat\nبرشة': 1,
#  'جوائز': 3,
#  'للربح': 7,
#  '🎁🎈🎊': 2,
#  'بالكورة': 1,
#  'مغروم': 25,
#  'نيمار': 2,
#  'تحب': 71,
#  'تكون': 25,
#  '😉\nشرجي': 1,
#  'ligne': 24,
#  'hayya': 17,
#  'متاعك': 6,
#  'اربح': 19,
#  'برشة': 39,
#  'كادوات': 28,
#  'منهم': 1,
#  '4voyages': 1,
#  'au': 44,
#  'brésil': 3,
#  'باش': 96,
#  'تحضر': 11,
#  'final': 2,
#  '🇧🇷': 3,
#  '⚽': 3,
#  'neymarjrsfive': 3,
#  'تبعوا': 186,
#  'حصريا': 182,
#  'أهم': 231,
#  'أحداث': 218,
#  'الحلقة': 189,
#  'القادمة': 172,
#  'من': 373,
#  'مسلسل': 211,
#  'قطوسة': 174,
#  'الرماد': 164,
#  'معا': 2,
#  'tt': 178,
#  'كمّل': 2,
#  'تمتّع': 4,
#  'حتى': 13,
#  'آخر': 3,
#  'العام': 10,
#  'بال': 20,
#  'offre': 14,
#  'mriguel': 3,
#  'httpbitly2hty60m\n👍😀📱🎉🎁': 1,
#  'الشوالي': 12,
#  'عندو': 8,
#  'ما': 68,
#  'يقول': 2,
#  'قبل': 14,
#  'ماتش': 2,
#  'إنجلترا،': 1,
#  'برجولية': 1,
#  'كلام': 3,
#  'ياسر': 4,
#  'قوي': 2,
#  'يشرجي': 1,
#  'بالحق': 1,
#  '🇹🇳👌😀💪😍': 1,
#  'كلم': 8,
#  'لعزيز': 1,
#  'عليك': 19,
#  'العالم': 19,
#  'الكل': 34,
#  'بارخص': 7,
#  'الأسوام': 12,
#  '📱\nو': 7,
#  'تمتع': 21,
#  'بسوايع': 2,
#  'مكالمات': 5,
#  'إبتداءً': 2,
#  '11': 12,
#  'دينار': 19,
#  'أكهو': 7,
#  'لعبتنا': 9,
#  'اليوم': 66,
#  'فيها': 20,
#  'تساكر': 5,
#  'لسهريّة': 4,
#  'مهرجان': 3,
#  'قرطاج': 16,
#  'الليلة': 5,
#  '🎉🎫\nقولولنا': 2,
#  'شكون': 56,
#  'اللّي': 15,
#  'التصويرة': 1,
#  'تدخلوا': 7,
#  'معانا': 32,
#  'القرعة': 25,
#  '😁': 8,
#  'كانك': 22,
#  'gameur': 7,
#  '🎮،': 12,
#  'guitariste': 7,
#  'قمقوم': 7,
#  'sportif': 10,
#  'دلول': 7,
#  '🏅\nو': 6,
#  'لا': 10,
#  'juste': 8,
#  'ڤالڤ': 4,
#  '😎\nو': 9,
#  'تبدل': 9,
#  'الجو': 11,
#  'تبع': 12,
#  'la': 100,
#  'tournée': 8,
#  'غدوة': 76,
#  'الإثنين': 4,
#  '1902': 1,
#  'campus': 3,
#  'universitaire': 2,
#  'sousse': 1,
#  '🎓\nو': 1,
#  'برشا': 11,
#  'كدوات': 8,
#  '🎁': 15,
#  'صحيح': 1,
#  'خسرنا': 1,
#  'قدام': 5,
#  'الانقليز': 1,
#  'أما': 6,
#  'التوانسة': 8,
#  'بالروح': 1,
#  'الدم': 1,
#  'لأخر': 1,
#  'دقيقة\nالشوالي': 1,
#  'ميساج': 2,
#  'يحب': 3,
#  'يوصلهولكم': 1,
#  'بلجيكيا': 1,
#  '💓👌🇹🇳': 1,
#  '💪': 6,
#  'duo': 2,
#  'sim': 3,
#  'à': 102,
#  '2': 13,
#  'numéros': 2,
#  '📱🆒🎉\n➡': 1,
#  'httpbitly2ovemr7': 1,
#  'نقولو': 1,
#  'ماناش': 1,
#  'مروحين': 1,
#  'توا': 4,
#  'جات': 2,
#  'روح': 1,
#  'جديدة': 6,
#  '،': 20,
#  'نغمة': 1,
#  '🎶': 9,
#  'انشالله': 2,
#  'رابحين⚽👌': 1,
#  'ربي': 1,
#  'نجمة': 1,
#  'وهلال': 1,
#  'منتصرين': 1,
#  '🇹🇳😁⚽💪❤️': 1,
#  'عصام': 10,
#  'عمري': 1,
#  'ماريت': 1,
#  'توانسة': 2,
#  'كيف': 17,
#  'هكا': 2,
#  '🇹🇳': 12,
#  'خاطرنا': 12,
#  'بلادنا': 10,
#  'نظافتها': 8,
#  'أولوياتنا': 8,
#  '🏖️😍\nاتصالات': 6,
#  'اختارت': 8,
#  'عندها': 9,
#  'اعوام': 8,
#  'بش': 59,
#  'شركة': 8,
#  'مسؤولة': 8,
#  'إجتماعياً': 8,
#  '🔝\nموعدنا': 8,
#  'ڨابس🏝️😁': 1,
#  '🙂': 6,
#  'إن': 8,
#  'شاء': 10,
#  'الله': 12,
#  'عيدكم': 1,
#  'مبروك': 24,
#  'سنين': 2,
#  'دايمة': 2,
#  '🎊🎉': 3,
#  'المرة': 2,
#  'هاذي': 2,
#  '🇷🇺🏆': 1,
#  'يحكيلكم': 1,
#  'غادي': 1,
#  'تحضيرات': 4,
#  '⚽💪🇹🇳': 1,
#  'مزروب': 2,
#  'لازمك': 3,
#  'تخلص': 10,
#  'فاتورة': 6,
#  'التليفون': 6,
#  '🏃\u200d♂️': 1,
#  '🏦': 1,
#  'service': 40,
#  'paiement': 10,
#  'en': 65,
#  '📱': 49,
#  'متاع': 35,
#  'اتصالات': 126,
#  'تونس،': 38,
#  'خلصها': 3,
#  'بكل': 2,
#  'سرعة': 1,
#  'وسهولة': 1,
#  '😉': 19,
#  'bonàsavoir': 4,
#  '😄😁😆': 1,
#  '💻': 28,
#  '🎞': 16,
#  'page': 24,
#  'إتصالات': 29,
#  'الترجي': 3,
#  '💪\n\n99': 1,
#  'سنة': 2,
#  'المجد': 2,
#  '🏆\n\nكل': 1,
#  'عام': 19,
#  'المكشخة': 1,
#  'بخير': 11,
#  '🎉': 39,
#  'بعوا': 3,
#  '23': 2,
#  'أوت': 11,
#  'طبرقة': 1,
#  'شجع': 6,
#  'malek': 24,
#  'jaziri': 21,
#  'ب': 34,
#  'commentaire': 25,
#  '💬': 3,
#  'تاڤي': 1,
#  'صحابك': 2,
#  'لم': 2,
#  'أكثر': 41,
#  'جامات👍': 1,
#  'الراكات': 1,
#  '🎾': 4,
#  'كيما': 22,
#  'وعدناكم😉': 1,
#  'بمناسبة': 8,
#  'عيد': 10,
#  'الأمّهات': 1,
#  'فرّحها': 1,
#  'بالpack': 1,
#  'لُمّيمة': 1,
#  '100': 8,
#  'remboursé': 3,
#  '😍📱🎉': 1,
#  'vivez': 5,
#  'les': 84,
#  'émotions': 3,
#  'très': 3,
#  'haute': 2,
#  'définition': 2,
#  'le': 95,
#  'samsung': 10,
#  'galaxy': 19,
#  's8': 8,
#  'aux': 11,
#  'meilleurs': 4,
#  'prix': 7,
#  'avec': 87,
#  'forfaits': 6,
#  'mobimobi': 2,
#  '200📱🎉\n➡': 2,
#  'httpbitly2rbkke7': 2,
#  'المنصورة': 1,
#  '💪😁\nغدوة': 1,
#  '12': 2,
#  'قربة': 1,
#  'نهار': 12,
#  'الأحد': 3,
#  '13': 3,
#  'الكرم': 1,
#  '📍✌️': 1,
#  'للفائز': 3,
#  'nizar': 4,
#  'ghrari': 1,
#  'إلي': 89,
#  'ربح': 5,
#  's9': 2,
#  '📱👍': 4,
#  'إنت': 33,
#  'زادة': 32,
#  'كان': 67,
#  'تربح': 23,
#  'اتبعنا': 1,
#  'باج': 1,
#  'télécom': 18,
#  'nouveaux': 2,
#  'ohméga\nالconnexion': 1,
#  'متوفاش': 2,
#  '🤗😁👏👂🎉\npour': 1,
#  'plus': 44,
#  'd’informations': 11,
#  'rendezvous': 5,
#  'sur': 29,
#  'httpsbitly2mj4z4x': 1,
#  'خلي': 2,
#  'حبك': 1,
#  'يتكلم': 1,
#  'pack': 6,
#  'lenovo': 1,
#  'vibe': 1,
#  'c2\n💑💓📱': 1,
#  'علىpage': 2,
#  'عملوا': 1,
#  'جو': 21,
#  'عالمي': 1,
#  'شوارع': 1,
#  'روسيا،': 1,
#  'اعملوا': 1,
#  'طلة': 2,
#  'عالفيديو\n🇷🇺👌🇹🇳⚽📣🎉': 1,
#  'الأمهات،': 1,
#  'تودكم': 1,
#  'بأعز': 9,
#  'الكدوات': 1,
#  '🎁🎉\nاكتبولنا': 1,
#  'كومنتار': 1,
#  'كلمة': 3,
#  'تعبّر': 1,
#  'عليها': 4,
#  'ولا': 53,
#  'جملة': 2,
#  'توصف': 1,
#  'حبّك': 1,
#  'ليها': 1,
#  '😍\nبالكومنترات': 1,
#  'أوصفوها': 1,
#  'وبles': 1,
#  'chèques': 6,
#  'cadeaux': 14,
#  'fatales': 4,
#  'فرحوها': 1,
#  '📝': 4,
#  'wwwfatalestn': 1,
#  'اللي': 41,
#  'يحط': 2,
#  'كومنترات،': 1,
#  'فيهم': 3,
#  'lavieestmaman': 1,
#  'يربح': 1,
#  'chèque': 1,
#  'cadeau': 4,
#  'بقيمة': 2,
#  '200د': 1,
#  'عند': 8,
#  '🎊✨': 1,
#  'البيرو': 1,
#  'الدار🏡🏢': 1,
#  'خلص': 4,
#  'تاليفونك': 4,
#  'الليل': 1,
#  'النهار☀️🌠': 1,
#  'أبدعو': 1,
#  'يشهد': 1,
#  'بينا': 1,
#  '👌🇹🇳💓⚽': 1,
#  'يااااا': 2,
#  'ياو': 4,
#  'حرت': 2,
#  'معندكش': 2,
#  'منين': 2,
#  'تصب': 2,
#  'فلوس💵': 2,
#  'sos': 2,
#  'solde': 4,
#  '🆘متع': 2,
#  'مايخليهاش': 2,
#  'بيك': 2,
#  'يعطيك': 2,
#  'تسبقة': 2,
#  'ل5': 2,
#  'د': 14,
#  'تتمتع': 4,
#  'بالservice': 2,
#  'إضغط': 3,
#  'على150😉': 1,
#  'الجمعة': 3,
#  '1602': 1,
#  'faculté': 1,
#  'de': 240,
#  'médecine': 1,
#  'monastir': 1,
#  '⚕️\nو': 1,
#  'الإربعاء': 2,
#  '1402': 1,
#  'bizerte': 1,
#  'فيكس': 2,
#  '☎\nفي': 1,
#  'أي': 3,
#  'وقت': 13,
#  'مكان': 1,
#  'مع😄😃': 1,
#  'ligne\nالدنيا': 1,
#  'تسهال\nhttpbitly2yhjtzp': 1,
#  'يستناو': 14,
#  'حلقة': 54,
#  'نوّدوهم': 1,
#  'بمقتطف': 1,
#  'للحلقات': 1,
#  'فاتوا': 2,
#  '\U0001f929': 3,
#  '2102': 1,
#  'sfax': 2,
#  'route': 1,
#  'l’aéroport': 1,
#  '🎓': 1,
#  'توّا': 4,
#  'سخّن': 2,
#  'للماتش': 3,
#  '🎶😄🇹🇳🇷🇺': 1,
#  '🎮': 12,
#  '🏅و': 1,
#  'قالق': 4,
#  '😎': 12,
#  'طيرلك': 1,
#  'الڤلڤ': 7,
#  'تنظم': 1,
#  'experience': 1,
#  'كونوا': 4,
#  'حاضرين': 6,
#  'تلعبو': 5,
#  'تربحو': 8,
#  'تبعو': 1,
#  'عل': 2,
#  'متاعنا': 5,
#  'تعرفو': 4,
#  'détails': 7,
#  'قريباً': 1,
#  'by': 36,
#  'telecom': 26,
#  'روووسيا': 2,
#  '🇷🇺🇷🇺🇷🇺': 2,
#  '🇹🇳🇹🇳🇹🇳\nو': 1,
#  'انتوما': 9,
#  'قولولنا': 7,
#  'كيفاش': 18,
#  'تسخنوا': 1,
#  '⚽⚽': 1,
#  'تشجعوا': 1,
#  'النسور': 1,
#  '🦅🦅': 2,
#  '🎊🎉هبطوا': 1,
#  'فيديو': 3,
#  'publique': 1,
#  'بروفيلك\nو': 1,
#  'متنساوش': 1,
#  'الhashtag': 1,
#  'وتربحوا': 1,
#  'smartphone': 51,
#  '20': 7,
#  'ans': 2,
#  'téléphonie': 2,
#  'mobile': 17,
#  'grâce': 2,
#  'd': 5,
#  'un': 69,
#  's7': 5,
#  'acheté': 3,
#  'j1': 3,
#  'offert': 3,
#  '😲': 5,
#  '🆓\n➡': 2,
#  'httpbitly2oaeymu': 3,
#  '😍\nاتصالات': 2,
#  'شاطئ': 1,
#  'المرسى🏖️': 1,
#  'notre': 28,
#  'fierté': 1,
#  'nationale': 2,
#  'champion': 12,
#  'né': 1,
#  'qui': 29,
#  'ne': 4,
#  'cesse': 2,
#  'nous': 8,
#  'impressionner': 1,
#  'ses': 5,
#  'exploits': 1,
#  'sa': 7,
#  'rage': 1,
#  'vaincre\nce': 1,
#  'film': 7,
#  'décrit': 1,
#  'son': 10,
#  'glorieux': 1,
#  'parcours': 1,
#  'malgré': 1,
#  'hauts': 1,
#  'bas': 1,
#  'blessures': 1,
#  'mais': 1,
#  'montre': 1,
#  'aussi': 1,
#  'toute': 6,
#  'détermination': 1,
#  'pour': 67,
#  'relever': 1,
#  'défis': 1,
#  'difficiles': 1,
#  '\ntennis': 1,
#  'malekjaziri': 3,
#  'championtunisien': 2,
#  'tunisietelecom': 6,
#  'الrecharge': 1,
#  'شرجي': 4,
#  '💳': 7,
#  '📱en': 1,
#  'clics': 1,
#  'غير': 30,
#  'déplacement': 1,
#  '😃': 12,
#  '⬇️': 16,
#  'httpsgooglmntnny': 3,
#  'jeu': 36,
#  'طلّع': 25,
#  'الكلمة': 2,
#  'كل': 95,
#  'يوم': 19,
#  'تربحك': 5,
#  'عديدة': 1,
#  '😁🎁': 1,
#  'اطّلعها': 1,
#  'نعاونوك': 1,
#  'بdes': 1,
#  'indices،': 1,
#  'تبّعهم': 1,
#  'الرابحين': 3,
#  '🎉🎈\nhttpbitly2qqhlpb': 1,
#  'شنية': 30,
#  'الرقم': 2,
#  'الناقص': 5,
#  'السلسلة': 1,
#  '🤔\nطلع': 2,
#  'واربح': 14,
#  'une': 27,
#  'carte': 14,
#  'recharge': 8,
#  '🎉😉': 1,
#  'تحط': 7,
#  'ذمتكم': 4,
#  'تاليفون': 4,
#  's9s9': 1,
#  'لولانين': 1,
#  'réservez': 3,
#  '19': 2,
#  'مارس': 2,
#  'site': 5,
#  'web': 1,
#  'bitly2g9z5fo': 1,
#  'مشترك': 2,
#  'fixe': 7,
#  '☎️': 10,
#  'فاتورتك': 4,
#  'الدار': 4,
#  'اضمن': 1,
#  'راحتك': 2,
#  'ووقتك': 1,
#  '🕑\nلمزيد': 1,
#  'المعلومات': 1,
#  'أدخل': 7,
#  'رابط': 2,
#  'هذا': 29,
#  'googlmntnny': 6,
#  'الفيكس': 2,
#  '☎': 3,
#  'درج': 1,
#  'زمان؟': 1,
#  'ب\npaiement': 1,
#  '💳💳\ntt': 1,
#  'مطمان': 1,
#  '🏠\nلاكثر': 1,
#  'معلومات': 33,
#  'كليكي': 22,
#  'هوني': 21,
#  '⬇️\nhttpsgooglmntnny': 1,
#  'حفل': 2,
#  'الجديد': 8,
#  'بالكادوات': 3,
#  '🎉🎁🎀': 1,
#  'العب': 1,
#  'معنا': 58,
#  'قد': 2,
#  'likes': 1,
#  '👍': 10,
#  'jadore': 1,
#  '❤\n\nعلى': 1,
#  'يتحلو': 1,
#  'فيسع': 3,
#  '🎁🎀🎉\n\nزيد': 1,
#  'كومينتي': 1,
#  '2018هاوجايين': 1,
#  'فرصتك': 1,
#  'تزيد': 5,
#  '😀': 5,
#  'تفرجوا': 43,
#  'أولاد': 14,
#  'مفيدة': 14,
#  '🆕': 12,
#  '👨👊': 3,
#  'قناة': 56,
#  'elhiwar': 26,
#  'ettounsi': 22,
#  'المساند': 5,
#  'الرسمي': 5,
#  'للمنتخب': 5,
#  'الوطني': 7,
#  'التونسي': 7,
#  'لكرة': 3,
#  'القدم': 4,
#  '🇹🇳⚽️💯': 2,
#  'ديمة': 19,
#  'القلب': 2,
#  '❤': 3,
#  '😊😋': 4,
#  'عودتكم': 2,
#  'تربحكم': 2,
#  '🎁🎈🎊🎉\nأيا': 1,
#  'طلعوا': 4,
#  'رقم': 4,
#  'الصحيح': 1,
#  'تربحوا': 12,
#  '⚽⚽⚽\n3': 1,
#  'cartes': 8,
#  'تبعونا': 11,
#  'حصرياً': 43,
#  '👊': 1,
#  '🔝': 6,
#  'est': 14,
#  'partenaire': 7,
#  'officiel': 8,
#  '63eme': 2,
#  'edition': 3,
#  'du': 67,
#  'championnat': 6,
#  '🥇🥈🥉🏆': 3,
#  'arabe': 5,
#  'tennis': 4,
#  '🎾🎾': 3,
#  'se': 3,
#  'déroule': 1,
#  '17': 1,
#  '26': 1,
#  'août': 3,
#  'hammamet': 4,
#  'bonne': 7,
#  'chance': 7,
#  'nos': 8,
#  'représentants': 1,
#  'nationaux💪💪👍👍': 1,
#  'عيش': 6,
#  'لحظة': 11,
#  'hd': 3,
#  'packs': 10,
#  'huawei': 3,
#  '🆒😲\n⬅': 1,
#  'httpbitly2o1b0mu': 2,
#  'للباس': 1,
#  'التقليدي': 1,
#  'bot': 1,
#  'قرر': 1,
#  'يلبس': 2,
#  'تونسي😃': 1,
#  'botمغروم': 1,
#  'بالتقليدي': 1,
#  'أبعثلنا': 1,
#  'تصاورك': 1,
#  '🖼️': 1,
#  'تصاور': 1,
#  'ولادك': 1,
#  'أحدث': 15,
#  'تاج': 20,
#  'الحاضرة': 14,
#  '📱🎉': 1,
#  'موجودين': 1,
#  'عندtt': 1,
#  'وزيد\n100': 1,
#  'remboursés': 1,
#  '😁💰\nلأكثر': 1,
#  'httpsgooglfp1wvh': 1,
#  'أول': 13,
#  'واحد': 31,
#  'يعرف': 4,
#  'الجاية': 3,
#  'تابعنا': 1,
#  'ليوم': 19,
#  'عالباج': 1,
#  'صيفك': 1,
#  'دنيا': 4,
#  'أخرى': 4,
#  'fest': 1,
#  'music': 1,
#  'كورنيش': 2,
#  'المهدية': 2,
#  '🎊': 16,
#  '18': 2,
#  'بوجعفر': 1,
#  'السبت': 1,
#  'صقانس': 1,
#  '🔝💪': 1,
#  '🆕👌': 5,
#  '👨👔': 4,
#  '0902': 1,
#  'gare': 1,
#  'tunis': 6,
#  'تتفرجوا': 8,
#  '🔥': 5,
#  'الأخيرة': 5,
#  'كانت': 3,
#  'ألوان': 3,
#  'الرياضي': 4,
#  '🇧🇪': 1,
#  'ماتكون': 1,
#  'أحمر': 1,
#  'أصفر': 1,
#  'sponsorofficielest': 1,
#  'مباراة': 4,
#  'ضد': 4,
#  'منتخب': 7,
#  'بلاد': 5,
#  'الباسك': 2,
#  'tt\nو': 2,
#  'نسور': 3,
#  '\nen': 2,
#  'exclusivité': 7,
#  'ici': 12,
#  'httpbitly2hplrvy\n⚽️😁': 1,
#  '👨': 1,
#  'الرماد💻🎞': 3,
#  '👍😉': 1,
#  'الرماد💻': 7,
#  'نحكيو': 15,
#  'المجموعة': 8,
#  'الأهم': 1,
#  'عندنا': 4,
#  'الكل،': 1,
#  'مانيش': 1,
#  'نحكي': 1,
#  'برشة،': 1,
#  'نخليكم': 1,
#  'تحليلو': 1,
#  'لمجموعة': 3,
#  'continue': 2,
#  'agir': 1,
#  'tant': 1,
#  'qu’entreprise': 1,
#  'socialement': 1,
#  'responsable': 1,
#  'relance': 1,
#  'l’action': 1,
#  'nettoyage': 1,
#  'des': 74,
#  'plages': 2,
#  '«': 6,
#  'gardons': 1,
#  'propres': 1,
#  '»\nle': 1,
#  'concept': 2,
#  'consiste': 1,
#  'inciter': 1,
#  'baigneurs': 1,
#  'ramasser': 1,
#  'déchets': 3,
#  'plage': 2,
#  'transformer': 1,
#  'accès': 1,
#  'wifi': 3,
#  'via': 5,
#  'dispositif': 2,
#  'dédié\n•': 1,
#  'l’écran': 1,
#  'kilos': 1,
#  'seront': 2,
#  'convertis': 1,
#  'gb': 2,
#  'd’internet': 1,
#  'temps': 2,
#  'réel': 1,
#  'affichés': 1,
#  'compteur': 1,
#  'l’écran\n•': 1,
#  'fois': 4,
#  'débloqué': 1,
#  'gens': 1,
#  'pourront': 1,
#  'profiter': 3,
#  'dans': 10,
#  'périmètre': 1,
#  '250m²': 1,
#  '50': 4,
#  'dinternet': 1,
#  'débit': 3,
#  'augmente': 1,
#  'ainsi': 4,
#  'fonction': 1,
#  'kg': 1,
#  'ramassés': 1,
#  'تليفون': 8,
#  '؟؟📱🎉\nساهل': 1,
#  'ماعليك': 7,
#  'تكتب': 2,
#  '📝كل': 1,
#  'حرف': 1,
#  'كومانتير': 1,
#  'يقص': 1,
#  'حد': 2,
#  '🚫\nو': 1,
#  'tagui': 3,
#  'مرة': 4,
#  'صحابك😊': 1,
#  '1202': 1,
#  'station': 1,
#  'beb': 1,
#  'saadoun': 1,
#  'موش': 3,
#  'الساقين': 1,
#  'قلب': 2,
#  'الجمهورو': 1,
#  'مشجعي': 1,
#  '🇹🇳⚽': 3,
#  '“el': 1,
#  'koura': 2,
#  'mouch': 1,
#  'kén': 1,
#  'fi': 3,
#  'sa9in': 1,
#  'el': 4,
#  '9alb': 1,
#  'jomhour': 1,
#  'w': 1,
#  'mouchaj3i': 1,
#  'tounéss': 1,
#  'kol”': 1,
#  'جديد': 16,
#  'انترنات': 19,
#  'صبّة': 9,
#  'معناها': 9,
#  'ماتصب': 9,
#  'بدينار': 19,
#  'أو': 9,
#  'تلقاهم': 9,
#  'بالوقت': 13,
#  'تليفونك': 17,
#  'code': 24,
#  'option': 11,
#  '😍📱': 5,
#  'internetsabba': 2,
#  'كي': 16,
#  'تدخل': 18,
#  'للقهوة': 1,
#  'تسمع': 1,
#  'اعطيني': 2,
#  'رابع': 2,
#  'رامي': 2,
#  '♦️': 1,
#  '♠️♣️': 1,
#  'ماتسمع': 1,
#  'ludo': 1,
#  'فيكم': 40,
#  'يستنى': 3,
#  'يتفرج': 4,
#  '؟؟': 12,
#  '😍': 20,
#  '🎞\nتبعوا': 1,
#  'الاولى': 3,
#  'زعمة': 10,
#  'شنوة': 15,
#  'يصير': 3,
#  '🤔\nما': 1,
#  'تنساوش': 13,
#  'تتبعونا': 3,
#  'تلشرجي': 10,
#  'الـ': 22,
#  'application': 10,
#  'جايين📲': 1,
#  'غني🎤': 1,
#  'تونس🎊🎉\nباش': 1,
#  'httpsgooglktuknu': 1,
#  'عدي': 1,
#  'صيف': 3,
#  'exceptionnel': 3,
#  '☀🌞😊\nبش': 1,
#  'تسهرو': 1,
#  'شارع': 3,
#  'الحبيب': 2,
#  'بورقيبة': 2,
#  'نابل': 1,
#  'troupe': 3,
#  'khnefes': 1,
#  'كونو': 1,
#  'الموعد': 3,
#  'متفلتوش': 3,
#  'الموزيكا': 4,
#  '🥁🎼🎷🎺': 1,
#  '💃🕺': 3,
#  'الكادوات': 11,
#  '🎉🎊': 2,
#  'لأول': 2,
#  'jeu🎮': 1,
#  'بالـ': 2,
#  'réalité': 1,
#  'augmentée': 1,
#  '😮\nقصر': 1,
#  'الوقت': 8,
#  'تلشرجي📲': 1,
#  'boutbila': 4,
#  '🥁': 2,
#  'إختار': 2,
#  'تعجبك🎶': 1,
#  'أعمل': 1,
#  '😍\nفاش': 1,
#  'تستنى': 6,
#  'ألعب': 2,
#  'جيب': 7,
#  'سكورك': 1,
#  '🎁🎉\nإنزل': 2,
#  'هنا': 7,
#  'httpsgooglvsnxen': 2,
#  'تطيّر': 5,
#  '؟\n😤🎈': 4,
#  '💨': 5,
#  'boutique': 4,
#  '⏩': 2,
#  '📍': 5,
#  'امشي': 5,
#  'لأقرب': 4,
#  'تفرّج': 6,
#  'العرض': 5,
#  '📯\n\nأفلام': 5,
#  '🎬': 6,
#  'موزيكا': 6,
#  '🎶\n\ndes': 3,
#  'jeux🏆': 5,
#  'و\n\n🎁bonusو\n\nوبرشا': 1,
#  '🎤': 8,
#  '🎲': 4,
#  'hayyatn': 1,
#  'بلال': 1,
#  'الباجي': 1,
#  'ينضم': 1,
#  'للمسلسل': 1,
#  'إسمو': 2,
#  'المسلسل': 6,
#  ...}

# %% [markdown]
# ## Donner la liste des mots et le nombre de leurs apparitions triés

# %%
words_df=pd.DataFrame(list(words.items()), columns=['Word' , 'count'])
words_df
words_df.sort_values('count' , ascending=False,inplace=True)

# %%
words_df
# Out:
#                         Word  count
# 21                             8725
# 12                         و    498
# 26                        في    404
# 77                        من    373
# 39                       على    258
# 437                       de    240
# 73                       أهم    231
# 74                     أحداث    218
# 78                     مسلسل    211
# 75                    الحلقة    189
# 71                     تبعوا    186
# 72                     حصريا    182
# 82                        tt    178
# 79                     قطوسة    174
# 18                        مع    174
# 76                   القادمة    172
# 80                    الرماد    164
# 16                      تونس    161
# 253                  اتصالات    126
# 182                        à    102
# 44                        et    100
# 152                       la    100
# 65                       باش     96
# 574                       كل     95
# 309                       le     95
# 333                      إلي     89
# 316                     avec     87
# 304                      les     84
# 154                     غدوة     76
# 808                      des     74
# ...                      ...    ...
# 2530               répondant      1
# 2502                   نشكرو      1
# 2501            bitly2nxl1tc      1
# 2500                   هذا⬅️      1
# 2480               المسابقات      1
# 2467              enchanteur      1
# 2468                  cinéma      1
# 2469                de\nlart      1
# 2470              renouvelle      1
# 2471                 soutien      1
# 2473                journées      1
# 2474      cinématographiques      1
# 2475                    leur      1
# 2476                   28ème      1
# 2477            😄🎉✌\nتابعونا      1
# 2478                  صفحتنا      1
# 2481                      😊😉      1
# 2498                  ميساج💬      1
# 2482                  تكونوا      1
# 2483                   💰💰\nو      1
# 2484                    لناس      1
# 2485                   👩‍👧‍👦      1
# 2487                     🐑😍❤      1
# 2490  joueursneymarjrsfivett      1
# 2492                 وتلشرجي      1
# 2493                 النغمة🎵      1
# 2494                   عاملة      1
# 2495               🎇\n\nإبعث      1
# 2497                  102129      1
# 5191                djalassi      1
#
# [5192 rows x 2 columns]

# %% [markdown]
# ## Donner seulement les mots qui ont apparu plus que 100 fois

# %%
words_df[words_df['count'] > 100]
# Out:
#         Word  count
# 21             8725
# 12         و    498
# 26        في    404
# 77        من    373
# 39       على    258
# 437       de    240
# 73       أهم    231
# 74     أحداث    218
# 78     مسلسل    211
# 75    الحلقة    189
# 71     تبعوا    186
# 72     حصريا    182
# 82        tt    178
# 79     قطوسة    174
# 18        مع    174
# 76   القادمة    172
# 80    الرماد    164
# 16      تونس    161
# 253  اتصالات    126
# 182        à    102

# %% [markdown]
# ## Savoir combien de fois ces mots ont apparu dans les messages des publications ["roussia","jayin","page","chance"]

# %%
#count of words in messages (posts)    
num_words=["roussia","jayin","page","chance"]

print (words_df[ words_df['Word'].isin(num_words) ])
# Out:
#         Word  count
# 264     page     24
# 703   chance      7
# 1    roussia      2
# 2      jayin      1

# %% [markdown]
# ## Grouper les publications par des mots-clés (TT par exemple)

# %%
df2['TT']=df2.message.str.contains('TT')
df2.head(50)
# Out:
#       total_comments              created_time  \
# 233             6250  2018-05-02T16:21:00+0000
# 555             3180  2017-11-11T18:55:46+0000
# 1035             272  2017-01-14T14:00:15+0000
# 349               99  2018-03-22T11:11:10+0000
# 293              549  2018-04-10T20:10:00+0000
# 289              557  2018-04-12T20:10:00+0000
# 1094             232  2016-12-27T18:00:09+0000
# 291              479  2018-04-11T20:10:00+0000
# 35               663  2018-06-15T17:00:02+0000
# 422              368  2018-02-16T19:50:00+0000
# 285              321  2018-04-13T20:10:00+0000
# 374              151  2018-03-09T20:10:00+0000
# 592              146  2017-10-18T13:37:02+0000
# 669            14904  2017-08-09T10:52:28+0000
# 389              166  2018-03-04T20:10:00+0000
# 381              263  2018-03-08T20:10:06+0000
# 429              209  2018-02-14T19:50:00+0000
# 398              235  2018-02-28T20:10:00+0000
# 425              208  2018-02-15T19:50:00+0000
# 265              214  2018-04-20T20:10:00+0000
# 383              160  2018-03-07T20:10:00+0000
# 267              114  2018-04-18T20:10:00+0000
# 266              192  2018-04-19T20:10:00+0000
# 318              225  2018-04-01T20:10:00+0000
# 419               99  2018-02-18T10:00:00+0000
# 370              159  2018-03-11T20:10:00+0000
# 368              154  2018-03-12T20:10:00+0000
# 283              229  2018-04-14T20:10:00+0000
# 329              364  2018-03-28T20:10:00+0000
# 264              136  2018-04-21T20:10:00+0000
# 385              137  2018-03-06T20:10:00+0000
# 317              200  2018-04-02T20:42:10+0000
# 350              228  2018-03-21T20:10:00+0000
# 316              167  2018-04-03T20:10:00+0000
# 395              171  2018-03-01T20:10:00+0000
# 20               589  2018-06-20T17:00:02+0000
# 404              155  2018-02-23T20:10:00+0000
# 839              324  2017-04-13T14:45:13+0000
# 403              183  2018-02-24T20:10:00+0000
# 282              190  2018-04-15T20:10:00+0000
# 260              140  2018-04-23T20:10:00+0000
# 372              150  2018-03-10T20:10:00+0000
# 391              166  2018-03-03T20:10:00+0000
# 393              165  2018-03-02T20:10:00+0000
# 399              185  2018-02-27T20:10:00+0000
# 215              225  2018-05-10T20:10:01+0000
# 13              2871  2018-06-22T17:03:36+0000
# 360              163  2018-03-16T20:10:00+0000
# 249              243  2018-04-26T20:10:00+0000
# 401              151  2018-02-26T20:10:00+0000
#
#                                     id  total_likes  \
# 233   117627008288878_1904195626298665        56709
# 555   117627008288878_1707092332675663        23074
# 1035  117627008288878_1390483674336532        22934
# 349   117627008288878_1856541627730732        17462
# 293   117627008288878_1879691842082377        16817
# 289   117627008288878_1881338555251039        14874
# 1094  117627008288878_1374836439234589        14845
# 291   117627008288878_1879693382082223        13964
# 35    117627008288878_1953010871417140        13361
# 422   117627008288878_1813043068747255        12199
# 285   117627008288878_1883547815030113        11997
# 374   117627008288878_1838919866159575        11636
# 592   117627008288878_1683388735046023        11596
# 669   117627008288878_1615041551880742        11574
# 389   117627008288878_1831298816921680        11459
# 381   117627008288878_1837569066294655        11069
# 429   117627008288878_1810793692305526        11000
# 398   117627008288878_1827408560644039        10769
# 425   117627008288878_1813041535414075        10764
# 265   117627008288878_1890167511034810        10634
# 383   117627008288878_1837554199629475        10608
# 267   117627008288878_1889027524482142        10427
# 266   117627008288878_1890158381035723        10371
# 318   117627008288878_1866432576741637        10292
# 419   117627008288878_1809358235782405        10149
# 370   117627008288878_1841737312544497        10120
# 368   117627008288878_1843753775676184        10080
# 283   117627008288878_1883555448362683        10073
# 329   117627008288878_1863960743655487        10029
# 264   117627008288878_1891167354268159        10027
# 385   117627008288878_1834889493229279        10002
# 317   117627008288878_1870740762977485         9996
# 350   117627008288878_1852967204754841         9941
# 316   117627008288878_1871793909538837         9936
# 395   117627008288878_1829999083718320         9920
# 20    117627008288878_1962217250496502         9914
# 404   117627008288878_1821368147914747         9854
# 839   117627008288878_1490128964372002         9722
# 403   117627008288878_1822599637791598         9689
# 282   117627008288878_1883604358357792         9682
# 260   117627008288878_1891171200934441         9640
# 372   117627008288878_1838925352825693         9627
# 391   117627008288878_1831294290255466         9606
# 393   117627008288878_1831289466922615         9472
# 399   117627008288878_1827405667310995         9461
# 215   117627008288878_1911884468863114         9448
# 13    117627008288878_1965937463457814         9433
# 360   117627008288878_1847798285271733         9422
# 249   117627008288878_1896378550413706         9416
# 401   117627008288878_1826082687443293         9390
#
#                                                 message     TT
# 233   YA ROUSSIA JAYIN يا روسيا جايين 2\n#YRJ #Tunis...  False
# 555   يااا روووسيااا جااييين و جااييين هاو جاااييين ...  False
# 1035  لكلنا نستناو في الmatch بالدقيقة و الدرج ⌚️⚽️\...  False
# 349   بالكورة مغروم و مع نيمار تحب تكون 😉\nشرجي lign...  False
# 293   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 289   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 1094  معا  TT كمّل تمتّع حتى آخر العام بال Offre Mri...   True
# 291   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 35    الشوالي عندو ما يقول قبل ماتش إنجلترا، برجولية...  False
# 422   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 285   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 374   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 592   كلم لعزيز عليك في العالم الكل بارخص الأسوام 📱\...  False
# 669   لعبتنا اليوم فيها تساكر لسهريّة مهرجان قرطاج ا...  False
# 389   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 381   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 429   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 398   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 425   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 265   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 383   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 267   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 266   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 318   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 419   كانك gameur مغروم 🎮، guitariste قمقوم 🎮، sport...  False
# 370   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 368   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 283   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 329   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 264   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 385   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 317   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 350   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 316   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 395   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 20    صحيح خسرنا قدام الانقليز أما التوانسة ديما بال...  False
# 404   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 839   Duo: La Sim à 2 Numéros !! 📱🆒🎉\n➡ http://bit.l...  False
# 403   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 282   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 260   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 372   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 391   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 393   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 399   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 215   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 13    نقولو ماناش مروحين 💪 توا جات روح جديدة ، نغمة ...  False
# 360   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 249   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False
# 401   تبعوا حصريا أهم أحداث الحلقة القادمة من مسلسل ...  False

# %%
df2.groupby(by=df2['TT']).count()
# Out:
#        total_comments  created_time    id  total_likes  message
# TT
# False            1154          1154  1154         1154     1154
# True              221           221   221          221      221

# %% [markdown]
# ## Grouper les publications par les dates de leur publication

# %%
type(df2.created_time.loc[0])
# Out:
# str

# %%
date_df=pd.DataFrame(pd.to_datetime(df2.created_time))

# %%
date_df
# Out:
#             created_time
# 233  2018-05-02 16:21:00
# 555  2017-11-11 18:55:46
# 1035 2017-01-14 14:00:15
# 349  2018-03-22 11:11:10
# 293  2018-04-10 20:10:00
# 289  2018-04-12 20:10:00
# 1094 2016-12-27 18:00:09
# 291  2018-04-11 20:10:00
# 35   2018-06-15 17:00:02
# 422  2018-02-16 19:50:00
# 285  2018-04-13 20:10:00
# 374  2018-03-09 20:10:00
# 592  2017-10-18 13:37:02
# 669  2017-08-09 10:52:28
# 389  2018-03-04 20:10:00
# 381  2018-03-08 20:10:06
# 429  2018-02-14 19:50:00
# 398  2018-02-28 20:10:00
# 425  2018-02-15 19:50:00
# 265  2018-04-20 20:10:00
# 383  2018-03-07 20:10:00
# 267  2018-04-18 20:10:00
# 266  2018-04-19 20:10:00
# 318  2018-04-01 20:10:00
# 419  2018-02-18 10:00:00
# 370  2018-03-11 20:10:00
# 368  2018-03-12 20:10:00
# 283  2018-04-14 20:10:00
# 329  2018-03-28 20:10:00
# 264  2018-04-21 20:10:00
# ...                  ...
# 665  2017-08-10 21:08:58
# 1351 2016-08-24 20:11:42
# 618  2017-09-09 19:44:04
# 616  2017-09-11 19:25:17
# 614  2017-09-13 20:45:40
# 675  2017-08-07 19:53:13
# 635  2017-08-25 19:29:04
# 1369 2016-08-19 19:25:43
# 1355 2016-08-22 19:05:59
# 617  2017-09-09 20:03:12
# 1353 2016-08-23 20:27:41
# 1338 2016-09-02 20:19:26
# 807  2017-05-01 17:48:59
# 657  2017-08-13 20:03:28
# 1337 2016-09-03 20:35:02
# 645  2017-08-19 21:20:24
# 1360 2016-08-20 20:18:20
# 651  2017-08-16 19:39:06
# 1354 2016-08-22 20:22:07
# 1332 2016-09-05 19:48:23
# 1336 2016-09-04 19:24:51
# 662  2017-08-11 18:53:00
# 1320 2016-09-10 19:11:52
# 679  2017-08-05 22:23:59
# 678  2017-08-06 20:38:20
# 1349 2016-08-25 20:12:13
# 1323 2016-09-09 19:42:42
# 671  2017-08-08 19:39:14
# 653  2017-08-15 20:04:57
# 659  2017-08-12 19:51:16
#
# [1375 rows x 1 columns]

# %% [markdown]
# ## Grouper les publications par mois

# %%
type(date_df.created_time.loc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# %matplotlib inline

fig= date_df.groupby(date_df.created_time.dt.month).count().plot(kind="bar",title="posts par mois")

# %% [markdown]
# ## Grouper les dates des publications par année

# %%
# %matplotlib inline

fig= date_df.groupby(date_df.created_time.dt.year).count().plot(kind="bar",legend=False, title="posts par année")

# %% [markdown]
# ## Grouper les publications par jour

# %%
# %matplotlib inline

fig= date_df.groupby(date_df.created_time.dt.day).count().plot(kind="bar",title="posts par jour")

# %% [markdown]
# ## Donner les publications qui ont été publiées à partir de 1-1-2018

# %%
date_df[date_df.created_time>"1-1-2018"]
# Out:
#            created_time
# 233 2018-05-02 16:21:00
# 349 2018-03-22 11:11:10
# 293 2018-04-10 20:10:00
# 289 2018-04-12 20:10:00
# 291 2018-04-11 20:10:00
# 35  2018-06-15 17:00:02
# 422 2018-02-16 19:50:00
# 285 2018-04-13 20:10:00
# 374 2018-03-09 20:10:00
# 389 2018-03-04 20:10:00
# 381 2018-03-08 20:10:06
# 429 2018-02-14 19:50:00
# 398 2018-02-28 20:10:00
# 425 2018-02-15 19:50:00
# 265 2018-04-20 20:10:00
# 383 2018-03-07 20:10:00
# 267 2018-04-18 20:10:00
# 266 2018-04-19 20:10:00
# 318 2018-04-01 20:10:00
# 419 2018-02-18 10:00:00
# 370 2018-03-11 20:10:00
# 368 2018-03-12 20:10:00
# 283 2018-04-14 20:10:00
# 329 2018-03-28 20:10:00
# 264 2018-04-21 20:10:00
# 385 2018-03-06 20:10:00
# 317 2018-04-02 20:42:10
# 350 2018-03-21 20:10:00
# 316 2018-04-03 20:10:00
# 395 2018-03-01 20:10:00
# ..                  ...
# 205 2018-05-14 11:22:16
# 81  2018-06-06 21:00:01
# 43  2018-06-14 09:00:01
# 106 2018-06-01 20:32:00
# 109 2018-06-01 16:25:00
# 279 2018-04-16 09:28:40
# 21  2018-06-20 16:02:50
# 76  2018-06-07 14:30:00
# 125 2018-05-30 12:15:00
# 194 2018-05-16 14:57:07
# 118 2018-05-31 12:47:03
# 115 2018-05-31 19:00:01
# 85  2018-06-06 14:33:54
# 126 2018-05-30 10:49:57
# 280 2018-04-16 09:17:58
# 4   2018-06-27 12:29:25
# 113 2018-06-01 09:00:00
# 100 2018-06-03 14:30:00
# 281 2018-04-16 09:09:58
# 91  2018-06-05 14:31:35
# 143 2018-05-28 13:37:49
# 7   2018-06-26 12:14:12
# 60  2018-06-10 21:00:00
# 132 2018-05-29 14:30:01
# 55  2018-06-11 21:00:01
# 142 2018-05-28 14:43:57
# 148 2018-05-27 11:00:00
# 3   2018-06-27 20:33:24
# 1   2018-06-29 18:00:01
# 0   2018-06-30 13:00:02
#
# [484 rows x 1 columns]
